# %%
import pandas as pd

# %%
df=pd.read_csv("datasets/sales_orders.csv")
df
# Out:
#   OrderID   Region     Product     Category  Quantity  UnitPrice   OrderDate  \
# 0    O001  Nairobi      Laptop  Electronics         2      80000  2025-01-10
# 1    O002  Mombasa       Phone  Electronics         5      25000  2025-01-11
# 2    O003   Kisumu      Tablet  Electronics         3      35000  2025-01-12
# 3    O004   Nakuru      Laptop  Electronics         1      80000  2025-01-13
# 4    O005  Nairobi  Headphones  Accessories        10       3000  2025-01-14
# 5    O006  Mombasa       Phone  Electronics         4      25000  2025-01-15
# 6    O007   Kisumu       Mouse  Accessories        15       1500  2025-01-16
# 7    O008   Nakuru    Keyboard  Accessories         8       2500  2025-01-17
# 8    O009  Nairobi      Tablet  Electronics         2      35000  2025-01-18
# 9    O010  Mombasa      Laptop  Electronics         3      80000  2025-01-19
#
#   SalesPerson
# 0        John
# 1        Mary
# 2       Peter
# 3       Susan
# 4       David
# 5       Grace
# ...

# %%
df.columns
# Out:
# Index(['OrderID', 'Region', 'Product', 'Category', 'Quantity', 'UnitPrice',
#        'OrderDate', 'SalesPerson'],
#       dtype='object')

# %%
df.shape
# Out:
# (10, 8)

# %%
df.dtypes
# Out:
# OrderID        object
# Region         object
# Product        object
# Category       object
# Quantity        int64
# UnitPrice       int64
# OrderDate      object
# SalesPerson    object
# dtype: object

# %%
df.head()
# Out:
#   OrderID   Region     Product     Category  Quantity  UnitPrice   OrderDate  \
# 0    O001  Nairobi      Laptop  Electronics         2      80000  2025-01-10
# 1    O002  Mombasa       Phone  Electronics         5      25000  2025-01-11
# 2    O003   Kisumu      Tablet  Electronics         3      35000  2025-01-12
# 3    O004   Nakuru      Laptop  Electronics         1      80000  2025-01-13
# 4    O005  Nairobi  Headphones  Accessories        10       3000  2025-01-14
#
#   SalesPerson
# 0        John
# 1        Mary
# 2       Peter
# 3       Susan
# 4       David

# %%
df.tail()
# Out:
#   OrderID   Region   Product     Category  Quantity  UnitPrice   OrderDate  \
# 5    O006  Mombasa     Phone  Electronics         4      25000  2025-01-15
# 6    O007   Kisumu     Mouse  Accessories        15       1500  2025-01-16
# 7    O008   Nakuru  Keyboard  Accessories         8       2500  2025-01-17
# 8    O009  Nairobi    Tablet  Electronics         2      35000  2025-01-18
# 9    O010  Mombasa    Laptop  Electronics         3      80000  2025-01-19
#
#   SalesPerson
# 5       Grace
# 6       James
# 7       Faith
# 8       Brian
# 9         Ann

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      10 non-null     object
#  1   Region       10 non-null     object
#  2   Product      10 non-null     object
#  3   Category     10 non-null     object
#  4   Quantity     10 non-null     int64
#  5   UnitPrice    10 non-null     int64
#  6   OrderDate    10 non-null     object
#  7   SalesPerson  10 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 772.0+ bytes

# %%
df.describe()
# Out:
#         Quantity     UnitPrice
# count  10.000000     10.000000
# mean    5.300000  36700.000000
# std     4.423423  32401.303129
# min     1.000000   1500.000000
# 25%     2.250000   8500.000000
# 50%     3.500000  30000.000000
# 75%     7.250000  68750.000000
# max    15.000000  80000.000000

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# OrderID        0
# Region         0
# Product        0
# Category       0
# Quantity       0
# UnitPrice      0
# OrderDate      0
# SalesPerson    0
# dtype: int64

# %%
df.drop(["OrderID"],axis=1,inplace=True)

# %%
df
# Out:
#     Region     Product     Category  Quantity  UnitPrice   OrderDate  \
# 0  Nairobi      Laptop  Electronics         2      80000  2025-01-10
# 1  Mombasa       Phone  Electronics         5      25000  2025-01-11
# 2   Kisumu      Tablet  Electronics         3      35000  2025-01-12
# 3   Nakuru      Laptop  Electronics         1      80000  2025-01-13
# 4  Nairobi  Headphones  Accessories        10       3000  2025-01-14
# 5  Mombasa       Phone  Electronics         4      25000  2025-01-15
# 6   Kisumu       Mouse  Accessories        15       1500  2025-01-16
# 7   Nakuru    Keyboard  Accessories         8       2500  2025-01-17
# 8  Nairobi      Tablet  Electronics         2      35000  2025-01-18
# 9  Mombasa      Laptop  Electronics         3      80000  2025-01-19
#
#   SalesPerson
# 0        John
# 1        Mary
# 2       Peter
# 3       Susan
# 4       David
# 5       Grace
# 6       James
# 7       Faith
# 8       Brian
# 9         Ann
