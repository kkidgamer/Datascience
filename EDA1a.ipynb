# %%
import pandas as pd

# %%
df=pd.read_csv("datasets/family_suitability.csv")
df
# Out:
#     Bedrooms  Area Safety (0-10)  Distance to School (km)  \
# 0          4                   2                     4.78
# 1          4                   4                     3.54
# 2          1                   9                     1.54
# 3          5                   1                     4.22
# 4          1                   8                     1.56
# ..       ...                 ...                      ...
# 95         2                   9                     0.76
# 96         4                   1                     3.56
# 97         1                   9                     1.05
# 98         1                   9                     0.61
# 99         5                   2                     3.10
#
#     Distance to Church (km)  Garden (0-No, 1-Yes)  House Age (Years)  \
# 0                      3.29                     0                 27
# 1                      3.88                     0                 21
# ...

# %%
df.shape
# Out:
# (100, 7)

# %%
df.columns
# Out:
# Index(['Bedrooms', 'Area Safety (0-10)', 'Distance to School (km)',
#        'Distance to Church (km)', 'Garden (0-No, 1-Yes)', 'House Age (Years)',
#        'Family Suitability'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Bedrooms                 100 non-null    int64
#  1   Area Safety (0-10)       100 non-null    int64
#  2   Distance to School (km)  100 non-null    float64
#  3   Distance to Church (km)  100 non-null    float64
#  4   Garden (0-No, 1-Yes)     100 non-null    int64
#  5   House Age (Years)        100 non-null    int64
#  6   Family Suitability       100 non-null    object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 5.6+ KB

# %%
df.dtypes
# Out:
# Bedrooms                     int64
# Area Safety (0-10)           int64
# Distance to School (km)    float64
# Distance to Church (km)    float64
# Garden (0-No, 1-Yes)         int64
# House Age (Years)            int64
# Family Suitability          object
# dtype: object

# %%
df.describe()
# Out:
#          Bedrooms  Area Safety (0-10)  Distance to School (km)  \
# count  100.000000          100.000000               100.000000
# mean     2.820000            5.710000                 2.500900
# std      1.671991            3.131124                 1.492584
# min      1.000000            1.000000                 0.520000
# 25%      1.000000            3.000000                 1.127500
# 50%      2.000000            6.000000                 1.900000
# 75%      5.000000            9.000000                 3.880000
# max      5.000000           10.000000                 4.990000
#
#        Distance to Church (km)  Garden (0-No, 1-Yes)  House Age (Years)
# count               100.000000                100.00         100.000000
# mean                  2.488100                  0.55          12.680000
# std                   1.456179                  0.50           9.448296
# min                   0.520000                  0.00           1.000000
# ...

# %%
df.head()
# Out:
#    Bedrooms  Area Safety (0-10)  Distance to School (km)  \
# 0         4                   2                     4.78
# 1         4                   4                     3.54
# 2         1                   9                     1.54
# 3         5                   1                     4.22
# 4         1                   8                     1.56
#
#    Distance to Church (km)  Garden (0-No, 1-Yes)  House Age (Years)  \
# 0                     3.29                     0                 27
# 1                     3.88                     0                 21
# 2                     1.02                     1                  8
# 3                     3.16                     0                 21
# 4                     1.33                     1                  7
#
#      Family Suitability
# 0   Not Good for Family
# 1   Not Good for Family
# 2  Yes, Good for Family
# 3   Not Good for Family
# 4   Not Good for Family

# %%
df.tail()
# Out:
#     Bedrooms  Area Safety (0-10)  Distance to School (km)  \
# 95         2                   9                     0.76
# 96         4                   1                     3.56
# 97         1                   9                     1.05
# 98         1                   9                     0.61
# 99         5                   2                     3.10
#
#     Distance to Church (km)  Garden (0-No, 1-Yes)  House Age (Years)  \
# 95                     0.53                     1                  5
# 96                     3.35                     0                 23
# 97                     1.96                     1                  4
# 98                     0.75                     1                  1
# 99                     4.06                     0                 29
#
#       Family Suitability
# 95  Yes, Good for Family
# 96   Not Good for Family
# 97  Yes, Good for Family
# 98  Yes, Good for Family
# 99   Not Good for Family

# %%
df.head(20)
# Out:
#     Bedrooms  Area Safety (0-10)  Distance to School (km)  \
# 0          4                   2                     4.78
# 1          4                   4                     3.54
# 2          1                   9                     1.54
# 3          5                   1                     4.22
# 4          1                   8                     1.56
# 5          1                   9                     0.52
# 6          5                   3                     4.42
# 7          1                  10                     1.90
# 8          5                   3                     4.79
# 9          1                   6                     1.57
# 10         5                   4                     4.11
# 11         4                   4                     3.20
# 12         5                   4                     4.73
# 13         5                   4                     4.49
# 14         1                  10                     1.94
# ...

# %%
df.tail(40)
# Out:
#     Bedrooms  Area Safety (0-10)  Distance to School (km)  \
# 60         5                   4                     3.37
# 61         1                   7                     1.12
# 62         5                   1                     3.16
# 63         2                   7                     0.88
# 64         4                   1                     4.66
# 65         1                   9                     1.08
# 66         1                   9                     1.70
# 67         1                   8                     1.43
# 68         1                   9                     0.76
# 69         2                   8                     1.55
# 70         1                  10                     1.63
# 71         4                   1                     3.63
# 72         4                   4                     4.13
# 73         1                   6                     0.73
# 74         1                   9                     1.40
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool
