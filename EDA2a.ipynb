# %%
import pandas as pd

# %%
df=pd.read_csv("datasets/BreadBasket.csv")
df
# Out:
#        Transaction           Item         date_time period_day weekday_weekend
# 0                1          Bread  30-10-2016 09:58    morning         weekend
# 1                2   Scandinavian  30-10-2016 10:05    morning         weekend
# 2                2   Scandinavian  30-10-2016 10:05    morning         weekend
# 3                3  Hot chocolate  30-10-2016 10:07    morning         weekend
# 4                3            Jam  30-10-2016 10:07    morning         weekend
# ...            ...            ...               ...        ...             ...
# 20502         9682         Coffee  09-04-2017 14:32  afternoon         weekend
# 20503         9682            Tea  09-04-2017 14:32  afternoon         weekend
# 20504         9683         Coffee  09-04-2017 14:57  afternoon         weekend
# 20505         9683         Pastry  09-04-2017 14:57  afternoon         weekend
# 20506         9684      Smoothies  09-04-2017 15:04  afternoon         weekend
#
# ...

# %%
df.columns
# Out:
# Index(['Transaction', 'Item', 'date_time', 'period_day', 'weekday_weekend'], dtype='object')

# %%
df.shape
# Out:
# (20507, 5)

# %%
df.dtypes
# Out:
# Transaction         int64
# Item               object
# date_time          object
# period_day         object
# weekday_weekend    object
# dtype: object

# %%
df.head(10)
# Out:
#    Transaction           Item         date_time period_day weekday_weekend
# 0            1          Bread  30-10-2016 09:58    morning         weekend
# 1            2   Scandinavian  30-10-2016 10:05    morning         weekend
# 2            2   Scandinavian  30-10-2016 10:05    morning         weekend
# 3            3  Hot chocolate  30-10-2016 10:07    morning         weekend
# 4            3            Jam  30-10-2016 10:07    morning         weekend
# 5            3        Cookies  30-10-2016 10:07    morning         weekend
# 6            4         Muffin  30-10-2016 10:08    morning         weekend
# 7            5         Coffee  30-10-2016 10:13    morning         weekend
# 8            5         Pastry  30-10-2016 10:13    morning         weekend
# 9            5          Bread  30-10-2016 10:13    morning         weekend

# %%
df.tail(49)
# Out:
#        Transaction                  Item         date_time period_day  \
# 20458         9658        Spanish Brunch  09-04-2017 11:30    morning
# 20459         9658  Extra Salami or Feta  09-04-2017 11:30    morning
# 20460         9659                   Tea  09-04-2017 11:31    morning
# 20461         9659                 Juice  09-04-2017 11:31    morning
# 20462         9659                  Cake  09-04-2017 11:31    morning
# 20463         9660                 Bread  09-04-2017 11:34    morning
# 20464         9664                Coffee  09-04-2017 11:40    morning
# 20465         9664                Coffee  09-04-2017 11:40    morning
# 20466         9664                 Bread  09-04-2017 11:40    morning
# 20467         9665                Coffee  09-04-2017 11:59    morning
# 20468         9665                 Juice  09-04-2017 11:59    morning
# 20469         9665        Spanish Brunch  09-04-2017 11:59    morning
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction      20507 non-null  int64
#  1   Item             20507 non-null  object
#  2   date_time        20507 non-null  object
#  3   period_day       20507 non-null  object
#  4   weekday_weekend  20507 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 801.2+ KB

# %%
df.describe()
# Out:
#         Transaction
# count  20507.000000
# mean    4976.202370
# std     2796.203001
# min        1.000000
# 25%     2552.000000
# 50%     5137.000000
# 75%     7357.000000
# max     9684.000000

# %%
df.isnull().sum()
# Out:
# Transaction        0
# Item               0
# date_time          0
# period_day         0
# weekday_weekend    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 20502    False
# 20503    False
# 20504    False
# 20505    False
# 20506    False
# Length: 20507, dtype: bool

# %%
df.drop(["Transaction","date_time"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Item               0
# period_day         0
# weekday_weekend    0
# dtype: int64

# %%
df.to_csv("cleaned-BreadBasket.csv",index=False)
print("Exported successfully")
# Out:
# Exported successfully
