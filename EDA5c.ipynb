# %%
import pandas as pd

# %%
df=pd.read_csv("datasets/movies.csv")
df
# Out:
#     movie_id                      title            genres  \
# 0          1      The Great Escape Plan   Action Thriller
# 1          2               Silent Orbit      Sci-Fi Drama
# 2          3           Laughing Matters            Comedy
# 3          4         Hearts in November     Romance Drama
# 4          5            Shadow Protocol        Action Spy
# 5          6           The Last Harvest             Drama
# 6          7               Robo Rangers  Animation Family
# 7          8            Midnight Static            Horror
# 8          9            Comic Con Chaos            Comedy
# 9         10             Galaxy Runners     Sci-Fi Action
# 10        11         The Wedding Detour    Comedy Romance
# 11        12               Iron Harvest      Action Drama
# 12        13           Whispering Pines   Horror Thriller
# 13        14        Second Chances Café     Drama Romance
# 14        15            Cartoon Kingdom  Animation Family
# 15        16              Quantum Heist   Sci-Fi Thriller
# 16        17         Neighborhood Watch            Comedy
# 17        18      The Long Goodbye Tour       Drama Music
# 18        19               Deep Current  Action Adventure
# 19        20     Letters from Yesterday     Romance Drama
# 20        21            Ghost Frequency            Horror
# 21        22                 Pixel Pals  Animation Comedy
# 22        23           Skyline Uprising     Action Sci-Fi
# 23        24  Coffee and Constellations    Romance Comedy
# 24        25        The Vanishing Point          Thriller
# 25        26           Backyard Bandits     Comedy Family
# 26        27          Frostbite Station     Horror Sci-Fi
# 27        28             The Understudy             Drama
# 28        29               Turbo Tumble  Animation Action
# 29        30              Harbor Lights     Romance Drama
# 30        31              Blackout City   Action Thriller
# 31        32              The Punchline      Comedy Drama
# 32        33               Orbit Eleven  Sci-Fi Adventure
# 33        34             Cabin Fourteen            Horror
# 34        35             The Recipe Box      Drama Family
# 35        36           Circuit Breakers     Action Sci-Fi
# 36        37                First Frost           Romance
# 37        38             Static Kingdom  Animation Sci-Fi
# 38        39                  The Alibi   Thriller Comedy
# 39        40                 Rivers End   Drama Adventure
#
#                                           description
# 0   A team of specialists plots a daring breakout ...
# 1   A lone astronaut drifts through space after lo...
# 2   Two rival stand-up comedians are forced to sha...
# 3   Two strangers reconnect every autumn at the sa...
# 4   An undercover agent must stop a rogue arms dea...
# 5   A farming family struggles to keep their land ...
# 6   A group of young inventors builds robot compan...
# 7   A late-night radio host starts receiving broad...
# 8   Convention volunteers scramble to fix a disast...
# 9   A crew of smugglers races across the galaxy to...
# 10  A cross-country road trip spirals out of contr...
# 11  A veteran returns home to fight corporate deve...
# 12  Campers uncover a decades-old secret buried be...
# 13  A chef rebuilds her life and her business afte...
# 14  A young princess teams up with talking forest ...
# 15  Scientists use experimental technology to pull...
# 16  Suburban neighbors form an overzealous patrol ...
# 17  An aging rock star embarks on one final tour a...
# 18  A salvage diver races rivals to recover treasu...
# 19  A woman discovers a box of old love letters th...
# 20  Paranormal investigators trace a haunting to a...
# 21  Video game characters come to life when the ar...
# 22  Survivors fight back after machines take contr...
# 23  A barista and an astronomer keep colliding on ...
# 24  A detective chases a suspect who seems to disa...
# 25  Two rival kids run competing lemonade empires ...
# 26  A remote arctic research team loses contact af...
# 27  A struggling actor gets one unexpected shot at...
# 28  Racing snails compete in the biggest garden ch...
# 29  A lighthouse keeper's quiet life changes when ...
# 30  A blackout across the city becomes cover for a...
# 31  A comedy writer rediscovers his voice after a ...
# 32  A space station crew must repair critical syst...
# 33  Friends on a weekend getaway realize the cabin...
# 34  A granddaughter follows a trail of recipes to ...
# 35  Underground racers modify illegal tech to surv...
# 36  Two rival ski instructors are forced to co-lea...
# 37  Robot citizens must restore power to their cit...
# 38  Two exes must pretend to be married to cover u...
# 39  A retired guide leads one last expedition down...

# %%
df.dtypes
# Out:
# movie_id        int64
# title          object
# genres         object
# description    object
# dtype: object

# %%
df.describe()
# Out:
#         movie_id
# count  40.000000
# mean   20.500000
# std    11.690452
# min     1.000000
# 25%    10.750000
# 50%    20.500000
# 75%    30.250000
# max    40.000000

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'genres', 'description'], dtype='object')

# %%
df.shape
# Out:
# (40, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   movie_id     40 non-null     int64
#  1   title        40 non-null     object
#  2   genres       40 non-null     object
#  3   description  40 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.4+ KB

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
df.describe()
# Out:
#         movie_id
# count  40.000000
# mean   20.500000
# std    11.690452
# min     1.000000
# 25%    10.750000
# 50%    20.500000
# 75%    30.250000
# max    40.000000

# %%
df.isnull().sum()
# Out:
# movie_id       0
# title          0
# genres         0
# description    0
# dtype: int64

# %%
df.drop(["movie_id"],axis=1,inplace=True)

# %%
df
# Out:
#                         title            genres  \
# 0       The Great Escape Plan   Action Thriller
# 1                Silent Orbit      Sci-Fi Drama
# 2            Laughing Matters            Comedy
# 3          Hearts in November     Romance Drama
# 4             Shadow Protocol        Action Spy
# 5            The Last Harvest             Drama
# 6                Robo Rangers  Animation Family
# 7             Midnight Static            Horror
# 8             Comic Con Chaos            Comedy
# 9              Galaxy Runners     Sci-Fi Action
# 10         The Wedding Detour    Comedy Romance
# 11               Iron Harvest      Action Drama
# 12           Whispering Pines   Horror Thriller
# 13        Second Chances Café     Drama Romance
# 14            Cartoon Kingdom  Animation Family
# 15              Quantum Heist   Sci-Fi Thriller
# 16         Neighborhood Watch            Comedy
# 17      The Long Goodbye Tour       Drama Music
# 18               Deep Current  Action Adventure
# 19     Letters from Yesterday     Romance Drama
# 20            Ghost Frequency            Horror
# 21                 Pixel Pals  Animation Comedy
# 22           Skyline Uprising     Action Sci-Fi
# 23  Coffee and Constellations    Romance Comedy
# 24        The Vanishing Point          Thriller
# 25           Backyard Bandits     Comedy Family
# 26          Frostbite Station     Horror Sci-Fi
# 27             The Understudy             Drama
# 28               Turbo Tumble  Animation Action
# 29              Harbor Lights     Romance Drama
# 30              Blackout City   Action Thriller
# 31              The Punchline      Comedy Drama
# 32               Orbit Eleven  Sci-Fi Adventure
# 33             Cabin Fourteen            Horror
# 34             The Recipe Box      Drama Family
# 35           Circuit Breakers     Action Sci-Fi
# 36                First Frost           Romance
# 37             Static Kingdom  Animation Sci-Fi
# 38                  The Alibi   Thriller Comedy
# 39                 Rivers End   Drama Adventure
#
#                                           description
# 0   A team of specialists plots a daring breakout ...
# 1   A lone astronaut drifts through space after lo...
# 2   Two rival stand-up comedians are forced to sha...
# 3   Two strangers reconnect every autumn at the sa...
# 4   An undercover agent must stop a rogue arms dea...
# 5   A farming family struggles to keep their land ...
# 6   A group of young inventors builds robot compan...
# 7   A late-night radio host starts receiving broad...
# 8   Convention volunteers scramble to fix a disast...
# 9   A crew of smugglers races across the galaxy to...
# 10  A cross-country road trip spirals out of contr...
# 11  A veteran returns home to fight corporate deve...
# 12  Campers uncover a decades-old secret buried be...
# 13  A chef rebuilds her life and her business afte...
# 14  A young princess teams up with talking forest ...
# 15  Scientists use experimental technology to pull...
# 16  Suburban neighbors form an overzealous patrol ...
# 17  An aging rock star embarks on one final tour a...
# 18  A salvage diver races rivals to recover treasu...
# 19  A woman discovers a box of old love letters th...
# 20  Paranormal investigators trace a haunting to a...
# 21  Video game characters come to life when the ar...
# 22  Survivors fight back after machines take contr...
# 23  A barista and an astronomer keep colliding on ...
# 24  A detective chases a suspect who seems to disa...
# 25  Two rival kids run competing lemonade empires ...
# 26  A remote arctic research team loses contact af...
# 27  A struggling actor gets one unexpected shot at...
# 28  Racing snails compete in the biggest garden ch...
# 29  A lighthouse keeper's quiet life changes when ...
# 30  A blackout across the city becomes cover for a...
# 31  A comedy writer rediscovers his voice after a ...
# 32  A space station crew must repair critical syst...
# 33  Friends on a weekend getaway realize the cabin...
# 34  A granddaughter follows a trail of recipes to ...
# 35  Underground racers modify illegal tech to surv...
# 36  Two rival ski instructors are forced to co-lea...
# 37  Robot citizens must restore power to their cit...
# 38  Two exes must pretend to be married to cover u...
# 39  A retired guide leads one last expedition down...

# %%
df.to_csv("cleaned-movies.csv",index=False)
print("Exported succesfully")
# Out:
# Exported succesfully
