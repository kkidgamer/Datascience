# %%
import pandas as pd

# %%
df=pd.read_csv("datasets/Cleaned-HotelBooking.csv")
df
# Out:
#               hotel  is_canceled  days_btwn_booked_and_reported  \
# 0      Resort Hotel            0                            342
# 1      Resort Hotel            0                              0
# 2      Resort Hotel            0                              7
# 3      Resort Hotel            0                             13
# 4      Resort Hotel            0                             14
# ...             ...          ...                            ...
# 87365    City Hotel            0                             23
# 87366    City Hotel            0                            102
# 87367    City Hotel            0                             34
# 87368    City Hotel            0                            109
# 87369    City Hotel            0                            205
#
#        arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                   2015               July                        27
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'days_btwn_booked_and_reported',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'Average_daily_rate',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'Year'],
#       dtype='object')

# %%
df.shape
# Out:
# (87370, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87370 entries, 0 to 87369
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87370 non-null  object
#  1   is_canceled                     87370 non-null  int64
#  2   days_btwn_booked_and_reported   87370 non-null  int64
#  3   arrival_date_year               87370 non-null  int64
#  4   arrival_date_month              87370 non-null  object
#  5   arrival_date_week_number        87370 non-null  int64
#  6   arrival_date_day_of_month       87370 non-null  int64
#  7   stays_in_weekend_nights         87370 non-null  int64
#  8   stays_in_week_nights            87370 non-null  int64
#  9   adults                          87370 non-null  int64
#  10  children                        87370 non-null  float64
#  11  babies                          87370 non-null  int64
# ...

# %%
df.describe()
# Out:
#         is_canceled  days_btwn_booked_and_reported  arrival_date_year  \
# count  87370.000000                   87370.000000       87370.000000
# mean       0.274969                      79.903251        2016.210290
# std        0.446501                      86.028178           0.686116
# min        0.000000                       0.000000        2015.000000
# 25%        0.000000                      11.000000        2016.000000
# 50%        0.000000                      49.000000        2016.000000
# 75%        1.000000                     125.000000        2017.000000
# max        1.000000                     709.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87370.000000               87370.000000
# mean                  26.839533                  15.815360
# std                   13.673204                   8.834842
# min                    1.000000                   1.000000
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# days_btwn_booked_and_reported       int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# days_btwn_booked_and_reported     0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 87365    False
# 87366    False
# 87367    False
# 87368    False
# 87369    False
# Length: 87370, dtype: bool

# %%
df.head()
# Out:
#           hotel  is_canceled  days_btwn_booked_and_reported  \
# 0  Resort Hotel            0                            342
# 1  Resort Hotel            0                              0
# 2  Resort Hotel            0                              7
# 3  Resort Hotel            0                             13
# 4  Resort Hotel            0                             14
#
#    arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0               2015               July                        27
# 1               2015               July                        27
# 2               2015               July                        27
# 3               2015               July                        27
# 4               2015               July                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                          1                        0                     0
# ...

# %%
df.tail()
# Out:
#             hotel  is_canceled  days_btwn_booked_and_reported  \
# 87365  City Hotel            0                             23
# 87366  City Hotel            0                            102
# 87367  City Hotel            0                             34
# 87368  City Hotel            0                            109
# 87369  City Hotel            0                            205
#
#        arrival_date_year arrival_date_month  arrival_date_week_number  \
# 87365               2017             August                        35
# 87366               2017             August                        35
# 87367               2017             August                        35
# 87368               2017             August                        35
# 87369               2017             August                        35
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 87365                         30                        2
# ...
